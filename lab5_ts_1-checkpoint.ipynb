# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as sts
from tqdm import tqdm
from sklearn import metrics
from datetime import timedelta
from numpy import linalg
import statsmodels

import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\KIRILL~1\AppData\Local\Temp/ipykernel_10748/838754263.py in <module>
#       5 import scipy.stats as sts
#       6 from tqdm import tqdm
# ----> 7 from sklearn import metrics
#       8 from datetime import timedelta
#       9 from numpy import linalg
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
def plot_acf_pacf(timeseries):
    """
    Функция, отображающая график временного ряда, 
    автокорреляционную функцию(ACF)
    и частную автокорреляционную функцию(PACF).
    """
    fig = plt.figure(figsize=(16,20))
    
    ax0 = fig.add_subplot(311)
    timeseries.plot(ax=ax0)
    ax0.set_title('График временного ряда')
    ax0.set_xlabel('Дата')
    ax0.set_ylabel('Количество новых заболеваний')
    
    ax1 = fig.add_subplot(312)
    fig = sm.graphics.tsa.plot_acf(timeseries, ax=ax1)
    ax1.set_title('Автокорреляционная функция')
    
    ax2 = fig.add_subplot(313)
    fig = sm.graphics.tsa.plot_pacf(timeseries, ax=ax2)
    ax2.set_title('Частная автокорреляционная функция')

def adf_test(timeseries):
    pvalue = sm.tsa.stattools.adfuller(timeseries)[1]
    print("Критерий Дики-Фуллера: p=%f" % pvalue)
    if pvalue > 0.05:
        print("Ряд нестационарен, нужно большее d")
    else:
        print("Ряд стационарен, d подходит")
    pvalue = sm.tsa.stattools.adfuller(timeseries, regression='c')[1]
    print("Критерий Дики-Фуллера с константой: p=%f" % pvalue)
    if pvalue > 0.05:
        print("Ряд нестационарен")
    else:
        print("Ряд стационарен")
    pvalue = sm.tsa.stattools.adfuller(timeseries, regression='ct')[1]
    print("Критерий Дики-Фуллера с константой и трендом: p=%f" % pvalue)
    if pvalue > 0.05:
        print("Ряд нестационарен")
    else:
        print("Ряд стационарен")
    pvalue = sm.tsa.stattools.adfuller(timeseries, regression='ctt')[1]
    print("Критерий Дики-Фуллера с константой, линейным и квадратичным трендом: p=%f" % pvalue)
    if pvalue > 0.05:
        print("Ряд нестационарен")
    else:
        print("Ряд стационарен")
    pvalue = sm.tsa.stattools.adfuller(timeseries, regression='nc')[1]
    print("Критерий Дики-Фуллера без константы и тренда: p=%f" % pvalue)
    if pvalue > 0.05:
        print("Ряд нестационарен")
    else:
        print("Ряд стационарен")

# %%
# функция с построением моделей
def adf_test3(timeseries):
    dif_1 = ts.diff().dropna()  
    print('\nШАГ 1')
    print('\nОцениваем модель авторегрессии 1го порядка с трендом и константой')
    print(statsmodels.tsa.ar_model.AutoReg(timeseries,lags=1,trend='ct').fit().summary())
    # проверка гипотезы о равенсте коэф авторегрессии 0
    pvalue = sm.tsa.stattools.adfuller(timeseries, regression='ct')[1]
    print("\nКритерий Дики-Фуллера с константой и линейным трендом (о равенсте коэф авторегрессии 0): p=%f" % pvalue)
    if pvalue < 0.05:
        print("\nРяд класса TS")  
    else:
        # нулевая гипотеза принимается 
        print('\nСтроим модель только с трендом и конст, чтобы убедиться, что правильно включили тренд')
        print(statsmodels.tsa.ar_model.AutoReg(timeseries,lags=0,trend='ct').fit().summary()) 
        print("\nЕсли коэффициент при тренде значим, ряд класса DS (случайное блуждание с дрейфом и детерминированным трендом)")         
    
    print('\nШАГ 2')
    print('\nОцениваем модель авторегрессии 1го порядка с константой')
    print(statsmodels.tsa.ar_model.AutoReg(timeseries,lags=1,trend='c').fit().summary())
    # проверка гипотезы о равенсте коэф авторегрессии 0
    pvalue = sm.tsa.stattools.adfuller(timeseries, regression='c')[1]
    print("\nКритерий Дики-Фуллера с константой (о равенсте коэф авторегрессии 0): p=%f" % pvalue)
    if pvalue > 0.05:
        # нулевая гипотеза принимается  
        print('\nСтроим модель только с конст, чтобы убедиться, что правильно включили конст')
        print(statsmodels.tsa.ar_model.AutoReg(dif_1,lags=0,trend='c').fit().summary())
        print("\nЕсли коэффициент при константе значим, ряд класса DS (случайное блуждание с дрейфом)")
    else:
        print("\nРяд класса TS (стационарный ряд с ненулевой средней)")
 
    print('\nШАГ 3')
    print('\nОцениваем модель авторегрессии 1го порядка без константы')
    print(statsmodels.tsa.ar_model.AutoReg(timeseries,lags=1,trend='n').fit().summary())
    # проверка гипотезы о равенсте коэф авторегрессии 0
    pvalue = sm.tsa.stattools.adfuller(timeseries, regression='nc')[1]
    print("\nКритерий Дики-Фуллера без константы и тренда (о равенсте коэф авторегрессии 0): p=%f" % pvalue)
    if pvalue > 0.05:
        # нулевая гипотеза принимается 
        print("\nРяд класса DS (случайное блуждание без дрейфа)")  
    else:
        print("\nРяд класса TS (процесс AR с нулевым мат ожиданием)")

# %% [markdown]
# # Загрузка данных

# %%
ts = pd.read_excel('Netherlands.xlsx', index_col='Data', parse_dates=['Data'])['New cases'].dropna() # !!!!!!!!!!
print(f"Длина временного ряда: {ts.shape[0]}")
ts = ts.resample('1W').mean()[:-1]
ts.head(15)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\KIRILL~1\AppData\Local\Temp/ipykernel_13680/2620372983.py in <module>
# ----> 1 ts = pd.read_excel('Netherlands.xlsx', index_col='Data', parse_dates=['Data'])['New cases'].dropna() # !!!!!!!!!!
#       2 print(f"Длина временного ряда: {ts.shape[0]}")
#       3 ts = ts.resample('1W').mean()[:-1]
#       4 ts.head(15)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1189                 ext = "xls"
#    1190             else:
# -> 1191                 ext = inspect_excel_format(
#    1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(content_or_path, storage_options)
#    1068         content_or_path = BytesIO(content_or_path)
#    1069
# -> 1070     with get_handle(
#    1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Netherlands.xlsx'

# %%
fig = plt.figure(figsize=(16,20))
    
ax0 = fig.add_subplot(311)
ts.plot(ax=ax0)
ax0.set_title('График временного ряда')
ax0.set_xlabel('Дата')
ax0.set_ylabel('Количество новых заболеваний')
# Out:
# Text(0, 0.5, 'Количество новых заболеваний')

# %% [markdown]
# # Определение типа ряда

# %%
adf_test3(ts)
# Out:
# ШАГ 1
#
# Оцениваем модель авторегрессии 1го порядка с трендом и константой
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:              New cases   No. Observations:                   97
# Model:                     AutoReg(1)   Log Likelihood                -838.702
# Method:               Conditional MLE   S.D. of innovations           1506.487
# Date:                Sun, 19 Dec 2021   AIC                             14.718
# Time:                        13:50:16   BIC                             14.825
# Sample:                    02-02-2020   HQIC                            14.762
#                          - 11-28-2021
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept       89.1273    317.721      0.281      0.779    -533.594     711.848
# trend            1.8784      6.309      0.298      0.766     -10.486      14.243
# New cases.L1     0.9295      0.041     22.662      0.000       0.849       1.010
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0759           +0.0000j            1.0759            0.0000
# -----------------------------------------------------------------------------
#
# Критерий Дики-Фуллера с константой и линейным трендом (о равенсте коэф авторегрессии 0): p=0.000079
#
# Ряд класса TS
#
# ШАГ 2
#
# Оцениваем модель авторегрессии 1го порядка с константой
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:              New cases   No. Observations:                   97
# Model:                     AutoReg(1)   Log Likelihood                -838.746
# Method:               Conditional MLE   S.D. of innovations           1507.182
# Date:                Sun, 19 Dec 2021   AIC                             14.698
# Time:                        13:50:16   BIC                             14.779
# Sample:                    02-02-2020   HQIC                            14.731
#                          - 11-28-2021
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept      167.1828    179.589      0.931      0.352    -184.806     519.171
# New cases.L1     0.9353      0.036     25.917      0.000       0.865       1.006
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0692           +0.0000j            1.0692            0.0000
# -----------------------------------------------------------------------------
#
# Критерий Дики-Фуллера с константой (о равенсте коэф авторегрессии 0): p=0.000143
#
# Ряд класса TS (стационарный ряд с ненулевой средней)
#
# ШАГ 3
#
# Оцениваем модель авторегрессии 1го порядка без константы
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:              New cases   No. Observations:                   97
# Model:                     AutoReg(1)   Log Likelihood                -839.177
# Method:               Conditional MLE   S.D. of innovations           1513.970
# Date:                Sun, 19 Dec 2021   AIC                             14.687
# Time:                        13:50:16   BIC                             14.740
# Sample:                    02-02-2020   HQIC                            14.708
#                          - 11-28-2021
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# New cases.L1     0.9526      0.031     30.680      0.000       0.892       1.013
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0498           +0.0000j            1.0498            0.0000
# -----------------------------------------------------------------------------
#
# Критерий Дики-Фуллера без константы и тренда (о равенсте коэф авторегрессии 0): p=0.002893
#
# Ряд класса TS (процесс AR с нулевым мат ожиданием)

# %% [markdown]
# # Определение порядка разности d и компонент p, q.

# %% [markdown]
# ### График временного ряда, АКФ и ЧАКФ

# %%
adf_test(ts)
plot_acf_pacf(ts)
# Out:
# Критерий Дики-Фуллера: p=0.000143
# Ряд стационарен, d подходит
# Критерий Дики-Фуллера с константой: p=0.000143
# Ряд стационарен
# Критерий Дики-Фуллера с константой и трендом: p=0.000079
# Ряд стационарен
# Критерий Дики-Фуллера с константой, линейным и квадратичным трендом: p=0.000472
# Ряд стационарен
# Критерий Дики-Фуллера без константы и тренда: p=0.002893
# Ряд стационарен

# %% [markdown]
# ### График первых разностей

# %%
dif_1 = ts.diff().dropna()
adf_test(dif_1)
plot_acf_pacf(dif_1)
# Out:
# Критерий Дики-Фуллера: p=0.000002
# Ряд стационарен, d подходит
# Критерий Дики-Фуллера с константой: p=0.000002
# Ряд стационарен
# Критерий Дики-Фуллера с константой и трендом: p=0.000019
# Ряд стационарен
# Критерий Дики-Фуллера с константой, линейным и квадратичным трендом: p=0.000083
# Ряд стационарен
# Критерий Дики-Фуллера без константы и тренда: p=0.000000
# Ряд стационарен

# %% [markdown]
# ### График вторых разностей

# %%
dif_2 = ts.diff().diff().dropna()
adf_test(dif_2)
plot_acf_pacf(dif_2)
# Out:
# Критерий Дики-Фуллера: p=0.000003
# Ряд стационарен, d подходит
# Критерий Дики-Фуллера с константой: p=0.000003
# Ряд стационарен
# Критерий Дики-Фуллера с константой и трендом: p=0.000018
# Ряд стационарен
# Критерий Дики-Фуллера с константой, линейным и квадратичным трендом: p=0.000029
# Ряд стационарен
# Критерий Дики-Фуллера без константы и тренда: p=0.000000
# Ряд стационарен

# %% [markdown]
# ### p и q определяются по графикам АКФ и ЧАКФ для подходящего значения d
#
# # Оценка параметров моделей
#
# * Log Lokehood - логарифм правдоподобия
# * S.D. of inovations - стандартная ошибка модели
# * AIC - информационный критерий Аккаике
# * BIC - информационный критерий Байеса
# * HQIC - информационный критерий Хеннана-Куинна
# * coef - значение коэффициента
# * P>|z| - p-value для гипотезы о незначимости коэффициента (если больше 0.05 - незначим)

# %% [markdown]
# # Поиск 5 лучших моделей: перебор параметров

# %%
d = range(0, 4)
q = range(0, 8)
p = range(0, 8)

from itertools import product

parameters = list(product(p,d,q))
len(parameters)
# Out:
# 256

# %%
# Может выполняться несколько минут
results = []
best_bic = float("inf")

for param in tqdm(parameters):
    #try except нужен, потому что на некоторых наборах параметров модель не обучается
    try:
        model = sm.tsa.ARIMA(ts, order=param).fit()
    except (ValueError, linalg.LinAlgError):
        continue
    bic = model.bic
    #сохраняем лучшую модель, bic, параметры
    if bic < best_bic:
        best_model = model
        best_bic = bic
        best_param = param
    results.append([param, model.bic])

result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'bic']
result_table.sort_values(by = 'bic', ascending=True).head(5)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 256/256 [01:34<00:00,  2.71it/s]
#    parameters          bic
# 45  (2, 1, 1)  1619.562756
# 47  (2, 2, 1)  1620.520786
# 32  (1, 2, 2)  1622.149753
# 76  (4, 2, 1)  1623.164915
# 62  (3, 2, 1)  1623.283561

# %% [markdown]
# ### Для начала поработаем с лучшей моделью (можно указать любую модель из 5)

# %%
model = sm.tsa.ARIMA(ts, order=(1, 2, 1)).fit() # !!!!!!!!!!!
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.New cases   No. Observations:                   95
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -808.056
# Method:                       css-mle   S.D. of innovations           1196.044
# Date:                Sun, 19 Dec 2021   AIC                           1624.112
# Time:                        13:51:52   BIC                           1634.327
# Sample:                    02-09-2020   HQIC                          1628.240
#                          - 11-28-2021
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.5089    130.438     -0.004      0.997    -256.162     255.145
# ar.L1.D2.New cases    -0.5708      0.404     -1.412      0.158      -1.363       0.222
# ma.L1.D2.New cases     0.6704      0.362      1.851      0.064      -0.039       1.380
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.7520           +0.0000j            1.7520            0.5000
# MA.1           -1.4917           +0.0000j            1.4917            0.5000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# ---
#
# # Проверка адекватности модели

# %%
fig, ax = plt.subplots(figsize=(16,8))
model.plot_predict(ax=ax)
fig.show()

# %%
pred = model.predict(typ='levels')
print('MSE =', metrics.mean_squared_error(ts[2:], pred))
print('RMSE =', np.sqrt(metrics.mean_squared_error(ts[2:], pred)))
print('MAE =', metrics.mean_absolute_error(ts[2:], pred))
print('MAPE =', metrics.mean_absolute_percentage_error(ts[2:], pred))
print('R2 =', metrics.r2_score(ts[2:], pred))
# Out:
# MSE = 1430521.150489475
# RMSE = 1196.0439584268945
# MAE = 531.8803127281695
# MAPE = 0.30977724617590124
# R2 = 0.9217696017410442

# %% [markdown]
# # Проверка нормальности остатков

# %%
resid = pd.DataFrame(model.resid, columns=['residuals']).sort_values(by='residuals')
adf_test(resid)
plot_acf_pacf(resid)
# Out:
# Критерий Дики-Фуллера: p=1.000000
# Ряд нестационарен, нужно большее d
# Критерий Дики-Фуллера с константой: p=1.000000
# Ряд нестационарен
# Критерий Дики-Фуллера с константой и трендом: p=1.000000
# Ряд нестационарен
# Критерий Дики-Фуллера с константой, линейным и квадратичным трендом: p=1.000000
# Ряд нестационарен
# Критерий Дики-Фуллера без константы и тренда: p=1.000000
# Ряд нестационарен

# %%
pvalue = sts.normaltest(resid['residuals'])[1]
print("Тест на нормальность: p = %f" % pvalue)
if pvalue > 0.05:
    print("Распределение остатков нормальное")
else:
    print("Распределение остатков ненормальное")

fig, ax = plt.subplots(figsize=(16,8))
resid.plot.kde(ax=ax)
plt.title('Распределение остатков')
plt.plot(resid, sts.norm.pdf(resid, resid.mean(), resid.std()), label='Нормальное')
plt.legend()
fig.show()
# Out:
# Тест на нормальность: p = 0.000000
# Распределение остатков ненормальное

# %%
fig, ax = plt.subplots(figsize=(16,8))
sm.qqplot(resid['residuals'], loc=resid['residuals'].mean(), scale = resid['residuals'].std(), line='45', ax=ax)
fig.show()

# %% [markdown]
# # Предсказание будущих показателей

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D2.New cases   No. Observations:                   95
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -808.056
# Method:                       css-mle   S.D. of innovations           1196.044
# Date:                Sun, 19 Dec 2021   AIC                           1624.112
# Time:                        13:51:53   BIC                           1634.327
# Sample:                    02-09-2020   HQIC                          1628.240
#                          - 11-28-2021
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.5089    130.438     -0.004      0.997    -256.162     255.145
# ar.L1.D2.New cases    -0.5708      0.404     -1.412      0.158      -1.363       0.222
# ma.L1.D2.New cases     0.6704      0.362      1.851      0.064      -0.039       1.380
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.7520           +0.0000j            1.7520            0.5000
# MA.1           -1.4917           +0.0000j            1.4917            0.5000
# -----------------------------------------------------------------------------
# """

# %%
weeks_pred = 2 # количество недель для предсказания !!!!!!!!!!!!!

print("Последняя дата во временном ряду: ", ts.index[-1])
print(f"Предсказание на {weeks_pred} недели, до: {ts.index[-1] + timedelta(weeks=weeks_pred)}")

fig, ax = plt.subplots(figsize=(16,8))
model.plot_predict(start=ts.index[-30], end=(ts.index[-1] + timedelta(weeks=weeks_pred)), ax=ax)
fig.show()
# Out:
# Последняя дата во временном ряду:  2021-11-28 00:00:00
# Предсказание на 2 недели, до: 2021-12-12 00:00:00

# %%
pred = model.predict(start=ts.index[-1] + timedelta(days=1), end=(ts.index[-1] + timedelta(weeks=weeks_pred)), typ='levels')
pred
# Out:
# 2021-12-05    56.996166
# 2021-12-12    15.346983
# Freq: W-SUN, dtype: float64

# %% [markdown]
# # Соберем ансамбль предсказаний

# %%
result_table.sort_values(by = 'bic', ascending=True).head(5)
# Out:
#    parameters          bic
# 45  (2, 1, 1)  1619.562756
# 47  (2, 2, 1)  1620.520786
# 32  (1, 2, 2)  1622.149753
# 76  (4, 2, 1)  1623.164915
# 62  (3, 2, 1)  1623.283561

# %% [markdown]
# ## Меняем параметры моделей на табличные

# %%
model1 = sm.tsa.ARIMA(ts, order=(1, 2, 1)).fit()
model2 = sm.tsa.ARIMA(ts, order=(0, 2, 4)).fit()
model3 = sm.tsa.ARIMA(ts, order=(0, 2, 5)).fit()
model4 = sm.tsa.ARIMA(ts, order=(0, 2, 2)).fit()
model5 = sm.tsa.ARIMA(ts, order=(0, 2, 1)).fit()

# %% [markdown]
# ## Сохраняем предсказания ансамбля и доверительные интервалы в Excel-файл

# %%
forecast = pd.DataFrame(index=pred.index)
res1 = model1.forecast(weeks_pred)
res2 = model2.forecast(weeks_pred)
res3 = model3.forecast(weeks_pred)
res4 = model4.forecast(weeks_pred)
res5 = model5.forecast(weeks_pred)
forecast['value1'] = res1[0]
forecast['value2'] = res2[0]
forecast['value3'] = res3[0]
forecast['value4'] = res4[0]
forecast['value5'] = res5[0]
forecast['result'] = (forecast['value1']+forecast['value2']+forecast['value3']+forecast['value4']+forecast['value5'])/5
forecast['left_border'] = [x[0] for x in res1[2]]
forecast['right_border'] = [x[1] for x in res1[2]]
forecast.to_excel('forecast.xlsx')
forecast
# Out:
#                value1     value2     value3     value4     value5     result  \
# 2021-12-05  56.996166  23.616146  16.455256  46.570688  41.748996  37.077451
# 2021-12-12  15.346983 -45.725019 -59.983720   2.775364  -6.868022 -18.890883
#
#             left_border  right_border
# 2021-12-05 -2287.206902   2401.199235
# 2021-12-12 -5436.207919   5466.901885

# %% [markdown]
# # Добавим сезонность и построим SARIMA
#
# Общий вид модели - **SARIMA (p,d,q) (P,D,Q) s**
#
# * p - порядок модели AR
# * d - порядок интегрирования
# * q - порядок модели MA
# * P - порядок сезонной составляющей SAR
# * D - порядок интегрирования сезонной составляющей
# * Q - порядок сезонной составляющей SMA
# * s - размерность сезонности
#
# ### Для начала надо провести сдвиг по сезонности, можно попробовать разные, рекомендуемый 4-6 месяцев.

# %%
months_seasonal = 6 # !!!!!!!!!!!!


ts_4m = ts.diff(4*months_seasonal).dropna()
print("Сезонная разность:")
adf_test(ts_4m)

print("-"*30)
dif_4m = ts.diff(4*months_seasonal).diff().dropna()
print("Интегрированная сезонная разность:")
adf_test(dif_4m)

# dif2_4m = ts.diff(30*monhts_seasonal).diff().diff().dropna()
# adf_test(dif2_4m)

fig = plt.figure(figsize=(16,30))
    
ax0 = fig.add_subplot(411)
ts_4m.plot(ax=ax0)
ax0.set_title('Сезонная разность d=0')
ax0.set_xlabel('Дата')
ax0.set_ylabel('Количество новых заболеваний')

ax0 = fig.add_subplot(412)
dif_4m.plot(ax=ax0)
ax0.set_title('Сезонная разность d=1')
ax0.set_xlabel('Дата')
ax0.set_ylabel('Количество новых заболеваний')

ax1 = fig.add_subplot(413)
fig = sm.graphics.tsa.plot_acf(dif_4m, ax=ax1)
ax1.set_title('Автокорреляционная функция')

ax2 = fig.add_subplot(414)
fig = sm.graphics.tsa.plot_pacf(dif_4m, ax=ax2)
ax2.set_title('Частная автокорреляционная функция')

fig.show()
# Out:
# Сезонная разность:
# Критерий Дики-Фуллера: p=0.000063
# Ряд стационарен, d подходит
# Критерий Дики-Фуллера с константой: p=0.000063
# Ряд стационарен
# Критерий Дики-Фуллера с константой и трендом: p=0.000587
# Ряд стационарен
# Критерий Дики-Фуллера с константой, линейным и квадратичным трендом: p=0.002004
# Ряд стационарен
# Критерий Дики-Фуллера без константы и тренда: p=0.000014
# Ряд стационарен
# ------------------------------
# Интегрированная сезонная разность:
# Критерий Дики-Фуллера: p=0.007262
# Ряд стационарен, d подходит
# Критерий Дики-Фуллера с константой: p=0.007262
# Ряд стационарен
# Критерий Дики-Фуллера с константой и трендом: p=0.047324
# Ряд стационарен
# Критерий Дики-Фуллера с константой, линейным и квадратичным трендом: p=0.004012
# Ряд стационарен
# Критерий Дики-Фуллера без константы и тренда: p=0.000399
# Ряд стационарен

# %% [markdown]
# ### P и Q определяются по графикам АКФ и ЧАКФ для подходящего значения D сезонной разности

# %%
# %%time 

#Модель SARIMA может тренироваться долго - если ставить значения параметров больше 1 время растет в геометрической прогресии... 

p = 1
d = 2
q = 1
P = 1
D = 1
Q = 1
s = 4*months_seasonal

sarima = sm.tsa.statespace.SARIMAX(ts, order=(p, d, q), 
                                seasonal_order=(P, D, Q, s)).fit()
print(sarima.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          New cases   No. Observations:                   97
# Model:             SARIMAX(1, 2, 1)x(1, 1, 1, 24)   Log Likelihood                -616.285
# Date:                            Sun, 19 Dec 2021   AIC                           1242.571
# Time:                                    13:51:56   BIC                           1253.884
# Sample:                                01-26-2020   HQIC                          1247.070
#                                      - 11-28-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7640      0.418     -1.829      0.067      -1.583       0.055
# ma.L1          0.8536      0.413      2.065      0.039       0.043       1.664
# ar.S.L24      -0.3112      3.604     -0.086      0.931      -7.374       6.752
# ma.S.L24      -0.2514      3.653     -0.069      0.945      -7.411       6.908
# sigma2      1.993e+06   2.57e+05      7.766      0.000    1.49e+06     2.5e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               208.60
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):              91.79   Skew:                            -1.59
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Wall time: 1.18 s

# %% [markdown]
# ---
#
# # Проверка адекватности сезонной модели

# %%
fig, ax = plt.subplots(figsize=(16,8))
pred = sarima.predict(typ='levels')
pred.plot(ax=ax)
ts.plot(ax=ax)
plt.legend()
fig.show()

# %%
print('MSE =', metrics.mean_squared_error(ts, pred))
print('RMSE =', np.sqrt(metrics.mean_squared_error(ts, pred)))
print('MAE =', metrics.mean_absolute_error(ts, pred))
print('MAPE =', metrics.mean_absolute_percentage_error(ts, pred))
print('R2 =', metrics.r2_score(ts, pred))
# Out:
# MSE = 1435299.2826074152
# RMSE = 1198.0397667053523
# MAE = 566.4236789211982
# MAPE = 0.4176840301984691
# R2 = 0.9204596268333047

# %% [markdown]
# # Проверка нормальности остатков

# %%
resid = pd.DataFrame(sarima.resid, columns=['residuals']).sort_values(by='residuals')
adf_test(resid)
plot_acf_pacf(resid)
# Out:
# Критерий Дики-Фуллера: p=0.998109
# Ряд нестационарен, нужно большее d
# Критерий Дики-Фуллера с константой: p=0.998109
# Ряд нестационарен
# Критерий Дики-Фуллера с константой и трендом: p=1.000000
# Ряд нестационарен
# Критерий Дики-Фуллера с константой, линейным и квадратичным трендом: p=1.000000
# Ряд нестационарен
# Критерий Дики-Фуллера без константы и тренда: p=0.985662
# Ряд нестационарен

# %%
pvalue = sts.normaltest(resid['residuals'])[1]
print("Тест на нормальность: p = %f" % pvalue)
if pvalue > 0.05:
    print("Распределение остатков нормальное")
else:
    print("Распределение остатков ненормальное")

fig, ax = plt.subplots(figsize=(16,8))
resid.plot.kde(ax=ax)
plt.title('Распределение остатков')
plt.plot(resid, sts.norm.pdf(resid, resid.mean(), resid.std()), label='Нормальное')
plt.legend()
fig.show()
# Out:
# Тест на нормальность: p = 0.000000
# Распределение остатков ненормальное

# %%
fig, ax = plt.subplots(figsize=(16,8))
sm.qqplot(resid['residuals'], loc=resid['residuals'].mean(), scale = resid['residuals'].std(), line='45', ax=ax)
fig.show()

# %% [markdown]
# # Предсказание будущих показателей

# %%
sarima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          New cases   No. Observations:                   97
# Model:             SARIMAX(1, 2, 1)x(1, 1, 1, 24)   Log Likelihood                -616.285
# Date:                            Sun, 19 Dec 2021   AIC                           1242.571
# Time:                                    13:51:57   BIC                           1253.884
# Sample:                                01-26-2020   HQIC                          1247.070
#                                      - 11-28-2021
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7640      0.418     -1.829      0.067      -1.583       0.055
# ma.L1          0.8536      0.413      2.065      0.039       0.043       1.664
# ar.S.L24      -0.3112      3.604     -0.086      0.931      -7.374       6.752
# ma.S.L24      -0.2514      3.653     -0.069      0.945      -7.411       6.908
# sigma2      1.993e+06   2.57e+05      7.766      0.000    1.49e+06     2.5e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               208.60
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):              91.79   Skew:                            -1.59
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
weeks_pred = 2 # количество недель для предсказания !!!!!!!!!!!!!

print("Последняя дата во временном ряду: ", ts.index[-1])
print(f"Предсказание на {weeks_pred} недели, до: {ts.index[-1] + timedelta(weeks=weeks_pred)}")

fig, ax = plt.subplots(figsize=(16,8))
pred = sarima.predict(start=ts.index[-20], end=(ts.index[-1] + timedelta(weeks=weeks_pred)), typ='levels')
pred.plot(ax=ax)
ts[-20:-1].plot(ax=ax)
plt.legend()
fig.show()
# Out:
# Последняя дата во временном ряду:  2021-11-28 00:00:00
# Предсказание на 2 недели, до: 2021-12-12 00:00:00

# %%
pred = sarima.predict(start=ts.index[-1] + timedelta(days=1), end=(ts.index[-1] + timedelta(weeks=weeks_pred)), typ='levels')
pred
# Out:
# 2021-12-05      65.800666
# 2021-12-12    1340.248382
# Freq: W-SUN, Name: predicted_mean, dtype: float64

# %% [markdown]
# ## Сохраняем предсказания и доверительные интервалы в Excel-файл

# %%
forecast = pd.DataFrame(columns=['value'], index=pred.index)
res = sarima.forecast(weeks_pred)
forecast['value'] = res
forecast.to_excel('forecast_sarima.xlsx')
forecast
# Out:
#                   value
# 2021-12-05    65.800666
# 2021-12-12  1340.248382
